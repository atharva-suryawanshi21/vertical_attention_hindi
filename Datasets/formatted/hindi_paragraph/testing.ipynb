# %%
import pickle

# %%
with open('labels_old.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data['ground_truth']['test']
# Out:
# {'iit_bombay_part_359_img_27.png': {'text': 'है पर मैं\nजानता हूँ\nये लोग'},
#  'iit_bombay_part_359_img_30.png': {'text': 'बल्कि उस\nउपरोक्त\nउदाहरण में'},
#  'iit_bombay_part_685_img_1.png': {'text': 'सहयोगियों\nको खलनायक\nसिद्ध करने'},
#  'iit_bombay_part_685_img_3.png': {'text': 'जानते कि\nवे इतिहास\nके किन'},
#  'iit_bombay_part_685_img_10.png': {'text': 'परिवार (\nसोनिया\nगाँधी का'},
#  'iit_bombay_part_685_img_17.png': {'text': 'पीएमके और\nद्रमुक\nजैसे'},
#  'iit_bombay_part_685_img_31.png': {'text': 'चुनावी\nतंत्र\nसत्तापक्ष'},
#  'iit_bombay_part_586_img_2.png': {'text': 'प्रतिशत\nलोग गरीबी\nरेखा से'},
#  'iit_bombay_part_586_img_21.png': {'text': 'सत्य है\n...राजनयिक\nके बहाने'},
#  'iit_bombay_part_586_img_30.png': {'text': 'के\nअन्तर्गत\nगुदा और'},
#  'iit_bombay_part_586_img_34.png': {'text': 'may follow\nstandardized\ncurricula'},
#  'iit_bombay_part_759_img_4.png': {'text': "देंगे ये\n'शीशे के\nहवालात'खौफ"},
# ...

# %%
test = {'a_1.png': {'text': 'है पर मैं\nजानता हूँ\nये लोग'},
 'a_2.png': {'text': 'बल्कि उस\nउपरोक्त\nउदाहरण में'},
 'a_3.png': {'text': 'सहयोगियों\nको खलनायक\nसिद्ध करने'},
 'a_4.png': {'text': 'जानते कि\nवे इतिहास\nके किन'}}

# %%
data['ground_truth']['test'] = test

# %%
with open('labels.pkl', 'wb') as file:
    pickle.dump(data, file)
